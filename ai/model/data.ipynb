# %%
from config import LatexGenerator

gen = LatexGenerator()

dataset = gen.generate_dataset(1000)

print(len(dataset))  # 1000
print(dataset[0])
# Out:
# 1000
# {'integrand': '\\int_{0}^{1}\\cos{x}dx', 'action': '0'}

# %%
import json

with open("../data/raw/dataset.json", "w", encoding="utf-8") as f:
    json.dump(dataset, f, indent=2, ensure_ascii=False)
